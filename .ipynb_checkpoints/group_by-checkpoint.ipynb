# %%
import pandas as pd
df = pd.read_csv("E:/csv_file/weather_by_city.csv")
df
# Out:
#          day      city  temperature  windspeed   event  Unnamed: 5
# 0   1/1/2017  new york           32          6    Rain         NaN
# 1   1/2/2017  new york           36          7   Sunny         NaN
# 2   1/3/2017  new york           28         12    Snow         NaN
# 3   1/4/2017  new york           33          7   Sunny         NaN
# 4   1/1/2017    mumbai           90          5   Sunny         NaN
# 5   1/2/2017    mumbai           85         12     Fog         NaN
# 6   1/3/2017    mumbai           87         15     Fog         NaN
# 7   1/4/2017    mumbai           92          5    Rain         NaN
# 8   1/1/2017     paris           45         20   Sunny         NaN
# 9   1/2/2017     paris           50         13  Cloudy         NaN
# 10  1/3/2017     paris           54          8  Cloudy         NaN
# 11  1/4/2017     paris           42         10  Cloudy         NaN

# %%
g = df.groupby("city")
g

# %%
for city, data in g:
    print("city:",city)
    print("\n")
    print("data:",data)
# Out:
# city: mumbai
#
#
# data:         day    city  temperature  windspeed  event  Unnamed: 5
# 4  1/1/2017  mumbai           90          5  Sunny         NaN
# 5  1/2/2017  mumbai           85         12    Fog         NaN
# 6  1/3/2017  mumbai           87         15    Fog         NaN
# 7  1/4/2017  mumbai           92          5   Rain         NaN
# city: new york
#
#
# data:         day      city  temperature  windspeed  event  Unnamed: 5
# 0  1/1/2017  new york           32          6   Rain         NaN
# 1  1/2/2017  new york           36          7  Sunny         NaN
# 2  1/3/2017  new york           28         12   Snow         NaN
# 3  1/4/2017  new york           33          7  Sunny         NaN
# city: paris
#
#
# data:          day   city  temperature  windspeed   event  Unnamed: 5
# 8   1/1/2017  paris           45         20   Sunny         NaN
# 9   1/2/2017  paris           50         13  Cloudy         NaN
# 10  1/3/2017  paris           54          8  Cloudy         NaN
# ...

# %%
g.get_group('mumbai')
# Out:
#         day    city  temperature  windspeed  event  Unnamed: 5
# 4  1/1/2017  mumbai           90          5  Sunny         NaN
# 5  1/2/2017  mumbai           85         12    Fog         NaN
# 6  1/3/2017  mumbai           87         15    Fog         NaN
# 7  1/4/2017  mumbai           92          5   Rain         NaN

# %%
g.max()
# Out:
#                day  temperature  windspeed  event  Unnamed: 5
# city
# mumbai    1/4/2017           92         15  Sunny         NaN
# new york  1/4/2017           36         12  Sunny         NaN
# paris     1/4/2017           54         20  Sunny         NaN

# %%
g.mean()
# Out:
#           temperature  windspeed  Unnamed: 5
# city
# mumbai          88.50       9.25         NaN
# new york        32.25       8.00         NaN
# paris           47.75      12.75         NaN

# %%
g.min()
# Out:
#                day  temperature  windspeed   event  Unnamed: 5
# city
# mumbai    1/1/2017           85          5     Fog         NaN
# new york  1/1/2017           28          6    Rain         NaN
# paris     1/1/2017           42          8  Cloudy         NaN

# %%
g.size()
# Out:
# city
# mumbai      4
# new york    4
# paris       4
# dtype: int64

# %%
g.count()
# Out:
#           day  temperature  windspeed  event  Unnamed: 5
# city
# mumbai      4            4          4      4           0
# new york    4            4          4      4           0
# paris       4            4          4      4           0

# %%
g.describe()
# Out:
#          temperature                                                   \
#                count   mean       std   min    25%   50%    75%   max
# city
# mumbai           4.0  88.50  3.109126  85.0  86.50  88.5  90.50  92.0
# new york         4.0  32.25  3.304038  28.0  31.00  32.5  33.75  36.0
# paris            4.0  47.75  5.315073  42.0  44.25  47.5  51.00  54.0
#
#          windspeed         ...              Unnamed: 5                       \
#              count   mean  ...    75%   max      count mean std min 25% 50%
# city                       ...
# mumbai         4.0   9.25  ...  12.75  15.0        0.0  NaN NaN NaN NaN NaN
# new york       4.0   8.00  ...   8.25  12.0        0.0  NaN NaN NaN NaN NaN
# paris          4.0  12.75  ...  14.75  20.0        0.0  NaN NaN NaN NaN NaN
#
#
#          75% max
# city
# mumbai   NaN NaN
# new york NaN NaN
# paris    NaN NaN
#
# [3 rows x 24 columns]

# %%
# %matplotlib inline
g.plot()
# Out:
# city
# mumbai      AxesSubplot(0.125,0.125;0.775x0.755)
# new york    AxesSubplot(0.125,0.125;0.775x0.755)
# paris       AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object
